# %%
#Import Libraries:

import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#Cleaned Datset Code:

df = pd.read_csv("../Data/horror_movies.csv")

df.drop(['adult', 'collection', 'poster_path','backdrop_path'], axis=1, inplace=True)
df.dropna(subset=['overview'], inplace=True)
df['release_date'] = pd.to_datetime(df['release_date'])
df_released = df.drop(df[df['status'] != 'Released'].index).reset_index(drop=True)
movie_df = df_released

# %%
movie_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 31142 entries, 0 to 31141
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 31142 non-null  int64
#  1   original_title     31142 non-null  str
#  2   title              31142 non-null  str
#  3   original_language  31142 non-null  str
#  4   overview           31142 non-null  str
#  5   tagline            12628 non-null  str
#  6   release_date       31142 non-null  datetime64[us]
#  7   popularity         31142 non-null  float64
#  8   vote_count         31142 non-null  int64
#  9   vote_average       31142 non-null  float64
#  10  budget             31142 non-null  int64
#  11  revenue            31142 non-null  int64
#  12  runtime            31142 non-null  int64
#  13  status             31142 non-null  str
#  14  genre_names        31142 non-null  str
#  15  collection_name    2281 non-null   str
# dtypes: datetime64[us](1), float64(2), int64(5), str(8)
# memory usage: 3.8 MB

# %%
movie_df.head(20)
# Out:
#         id                  original_title                           title  \
# 0   760161              Orphan: First Kill              Orphan: First Kill
# 1   760741                           Beast                           Beast
# 2   882598                           Smile                           Smile
# 3   756999                 The Black Phone                 The Black Phone
# 4   772450                      Presencias                       Presences
# 5   717728        Jeepers Creepers: Reborn        Jeepers Creepers: Reborn
# 6   762504                            Nope                            Nope
# 7   927341               Hunting Ava Bravo               Hunting Ava Bravo
# 8   760104                               X                               X
# 9   836225             The Exorcism of God             The Exorcism of God
# 10  801071  The Jack in the Box: Awakening  The Jack in the Box: Awakening
# 11  852830                     Torn Hearts                     Torn Hearts
# 12  758724                      The Cellar                      The Cellar
# 13  816952       My Best Friend's Exorcism       My Best Friend's Exorcism
# 14  755566                       Day Shift                       Day Shift
# 15  896448             Beneath the Surface             Beneath the Surface
# 16  629015                         Shut In                         Shut In
# 17  661791                       La abuela                 The Grandmother
# 18   25853                          Dahmer                          Dahmer
# 19  945657                     Titanic 666                     Titanic 666
#
#    original_language                                           overview  \
# 0                 en  After escaping from an Estonian psychiatric fa...
# 1                 en  A recently widowed man and his two teenage dau...
# 2                 en  After witnessing a bizarre, traumatic incident...
# 3                 en  Finney Blake, a shy but clever 13-year-old boy...
# 4                 es  A man who loses his wife and goes to seclude h...
# 5                 en  Forced to travel with her boyfriend to a horro...
# 6                 en  Residents in a lonely gulch of inland Californ...
# 7                 en  Billionaire sportsman Buddy King unwinds by hu...
# 8                 en  In 1979, a group of young filmmakers set out t...
# 9                 en  An American priest working in Mexico is consid...
# 10                en  When a vintage Jack-in-the-box is opened by a ...
# 11                en  A promising up-and-coming country duo seek out...
# 12                en  When Keira Woods' daughter mysteriously vanish...
# 13                en  The year is 1988. Abby and Gretchen have been ...
# 14                en  An LA vampire hunter has a week to come up wit...
# 15                en  A young woman survives a great white shark att...
# 16                en  A young single mother is held captive along wi...
# 17                es  A Paris model must return to Madrid where her ...
# 18                en  On February 15, 1992 in Milwaukee, Wisconsin, ...
# 19                en  After a mammoth cruise ship sails over the sit...
#
#                                              tagline release_date  popularity  \
# 0   There's always been something wrong with Esther.   2022-07-27    5088.584
# 1                                  Fight for family.   2022-08-11    2172.338
# 2                    Once you see it, it’s too late.   2022-09-23    1863.628
# 3                           Never talk to strangers.   2022-06-22    1071.398
# 4                                                NaN   2022-09-07    1020.995
# 5                                   Evil Rides Again   2022-09-15     821.605
# 6                              What’s a bad miracle?   2022-07-20     733.112
# 7                                "If I die, you die"   2022-04-01     574.832
# 8                     Dying to show you a good time.   2022-03-17     543.670
# 9   God and the Devil cannot exist in the same body.   2022-03-11     537.252
# 10     Once you open the box... you can't escape it.   2022-02-24     527.579
# 11                                               NaN   2022-05-20     525.876
# 12                       An ancient evil has awoken.   2022-03-25     513.757
# 13  True friendship is worth going to hell and back.   2022-09-29     501.921
# 14               Some jobs really go for the throat.   2022-08-10     449.683
# 15                  Prey you will make it out alive!   2022-04-01     412.340
# 16                 The will to live is found within.   2022-03-24     399.436
# 17                   Nobody will love you like I do.   2022-01-28     381.305
# 18                   The mind is a place of its own.   2002-06-21     378.390
# 19                                               NaN   2022-04-15     372.136
#
#     vote_count  vote_average    budget    revenue  runtime    status  \
# 0          902           6.9         0    9572765       99  Released
# 1          584           7.1         0   56000000       93  Released
# 2          114           6.8  17000000   45000000      115  Released
# 3         2736           7.9  18800000  161000000      103  Released
# 4           83           7.0         0          0        0  Released
# 5          125           5.8  20000000    2892594       88  Released
# 6         1684           7.0  68000000  170800000      130  Released
# 7           73           6.5         0          0       90  Released
# 8         1035           6.8  10000000   14257609      106  Released
# 9          637           7.3   1500000          0       98  Released
# 10         157           6.4         0          0       89  Released
# 11          39           6.1         0          0       97  Released
# 12         257           6.6         0          0       94  Released
# 13          43           6.1         0          0       96  Released
# 14        1129           6.9         0          0      113  Released
# 15          50           6.9         0          0       93  Released
# 16         224           7.2         0     304106       90  Released
# 17         272           5.9         0          0      100  Released
# 18         220           5.2    250000     144008      101  Released
# 19          98           6.0         0          0       91  Released
#
#                                           genre_names  \
# 0                                    Horror, Thriller
# 1                            Adventure, Drama, Horror
# 2                           Horror, Mystery, Thriller
# 3                                    Horror, Thriller
# 4                                              Horror
# 5                           Horror, Mystery, Thriller
# 6          Horror, Mystery, Science Fiction, Thriller
# 7   Action, Adventure, Crime, Drama, Horror, Myste...
# 8                           Horror, Mystery, Thriller
# 9                                              Horror
# 10                                             Horror
# 11                            Horror, Music, Thriller
# 12                                    Horror, Mystery
# 13                                     Comedy, Horror
# 14                    Action, Comedy, Fantasy, Horror
# 15                 Fantasy, Horror, Mystery, Thriller
# 16                                   Horror, Thriller
# 17                                      Drama, Horror
# 18                                      Drama, Horror
# 19                                   Horror, Thriller
#
#                 collection_name
# 0             Orphan Collection
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5   Jeepers Creepers Collection
# 6                           NaN
# 7                           NaN
# 8                  X Collection
# 9                           NaN
# 10   Jack in the Box Collection
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
